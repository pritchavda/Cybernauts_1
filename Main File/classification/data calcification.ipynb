# %%
import matplotlib as mp
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('solar_wind.csv')
df = pd.DataFrame(data)

# %%
df.head(100)
# Out:
#      period        timedelta  bx_gse  by_gse  bz_gse  theta_gse  phi_gse  \
# 0   train_a  0 days 00:00:00   -5.55    3.00    1.25      11.09   153.37
# 1   train_a  0 days 00:01:00   -5.58    3.16    1.17      10.10   151.91
# 2   train_a  0 days 00:02:00   -5.15    3.66    0.85       7.87   146.04
# 3   train_a  0 days 00:03:00   -5.20    3.68    0.68       6.17   146.17
# 4   train_a  0 days 00:04:00   -5.12    3.68    0.49       4.62   145.72
# ..      ...              ...     ...     ...     ...        ...      ...
# 95  train_a  0 days 01:35:00   -6.75    1.07    1.34      10.80   171.72
# 96  train_a  0 days 01:36:00   -5.84   -0.36    0.53       7.12   182.32
# 97  train_a  0 days 01:37:00   -6.75    1.44    1.09       8.79   168.71
# 98  train_a  0 days 01:38:00   -6.75    1.65    0.75       6.12   167.07
# 99  train_a  0 days 01:39:00   -6.80    1.80    0.61       4.98   166.07
#
#     bx_gsm  by_gsm  bz_gsm  theta_gsm  phi_gsm    bt  density   speed  \
# ...

# %%
df.head(10000)
# Out:
#        period        timedelta  bx_gse  by_gse  bz_gse  theta_gse  phi_gse  \
# 0     train_a  0 days 00:00:00   -5.55    3.00    1.25      11.09   153.37
# 1     train_a  0 days 00:01:00   -5.58    3.16    1.17      10.10   151.91
# 2     train_a  0 days 00:02:00   -5.15    3.66    0.85       7.87   146.04
# 3     train_a  0 days 00:03:00   -5.20    3.68    0.68       6.17   146.17
# 4     train_a  0 days 00:04:00   -5.12    3.68    0.49       4.62   145.72
# ...       ...              ...     ...     ...     ...        ...      ...
# 9995  train_a  6 days 22:35:00     NaN     NaN     NaN        NaN      NaN
# 9996  train_a  6 days 22:36:00     NaN     NaN     NaN        NaN      NaN
# 9997  train_a  6 days 22:37:00     NaN     NaN     NaN        NaN      NaN
# 9998  train_a  6 days 22:38:00     NaN     NaN     NaN        NaN      NaN
# 9999  train_a  6 days 22:39:00     NaN     NaN     NaN        NaN      NaN
#
# ...
